# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('e-finance dataset.csv')

# %%
df
# Out:
#                                                Authors  \
# 0    Beni E.H., Lagaisse B., Joosen W., Aly A., Bra...
# 1                                    Xiong H., Zhou Y.
# 2                Feng L., Zhang H., Tsai W.-T., Sun S.
# 3                     Rožkalne Z., Mukāns M., Vētra A.
# 4                Alshubiri F., Jamil S.A., Elheddad M.
# ..                                                 ...
# 223                Wood S.D., Trenter S.W., Brown S.W.
# 224                         Heilman M.E., Martell R.F.
# 225                                         Leech D.H.
# 226                                     Kanngiesser J.
# 227                                       Holland J.B.
#
#                                           Author(s) ID  \
# 0    57189258279;8933999000;22834655700;55841871100...
# 1                             57212174318;57212168803;
# 2     57194783804;56979549200;57050382000;57197771738;
# 3                  57211844555;56074676500;6506045608;
# ...

# %%
df.isnull().sum()
# Out:
# Authors                            0
# Author(s) ID                       0
# Title                              0
# Year                               0
# Source title                       1
# Volume                            48
# Issue                             81
# Art. No.                         201
# Page start                        22
# Page end                          29
# Page count                       224
# Cited by                          75
# DOI                               54
# Link                               0
# Affiliations                      14
# Authors with affiliations          2
# Abstract                           0
# Author Keywords                   48
# Index Keywords                   127
# Molecular Sequence Numbers       228
# Chemicals/CAS                    228
# Tradenames                       228
# Manufacturers                    228
# Funding Details                  209
# Funding Text 1                   204
# ...

# %%
# Dropping the columns containing a lot of null values.
new_df=df.dropna(thresh=df.shape[0]*0.5,how ='all',axis=1)

# %%
new_df
# Out:
#                                                Authors  \
# 0    Beni E.H., Lagaisse B., Joosen W., Aly A., Bra...
# 1                                    Xiong H., Zhou Y.
# 2                Feng L., Zhang H., Tsai W.-T., Sun S.
# 3                     Rožkalne Z., Mukāns M., Vētra A.
# 4                Alshubiri F., Jamil S.A., Elheddad M.
# ..                                                 ...
# 223                Wood S.D., Trenter S.W., Brown S.W.
# 224                         Heilman M.E., Martell R.F.
# 225                                         Leech D.H.
# 226                                     Kanngiesser J.
# 227                                       Holland J.B.
#
#                                           Author(s) ID  \
# 0    57189258279;8933999000;22834655700;55841871100...
# 1                             57212174318;57212168803;
# 2     57194783804;56979549200;57050382000;57197771738;
# 3                  57211844555;56074676500;6506045608;
# ...

# %%
new_df.isnull().sum()
# Out:
# Authors                           0
# Author(s) ID                      0
# Title                             0
# Year                              0
# Source title                      1
# Volume                           48
# Issue                            81
# Page start                       22
# Page end                         29
# Cited by                         75
# DOI                              54
# Link                              0
# Affiliations                     14
# Authors with affiliations         2
# Abstract                          0
# Author Keywords                  48
# References                       16
# Correspondence Address           37
# Publisher                        88
# ISSN                             54
# Language of Original Document     0
# Abbreviated Source Title         10
# Document Type                     0
# Publication Stage                 0
# Source                            0
# EID                               0
# ...

# %%
sns.countplot(y='Document Type',data=new_df)

# %%
sns.countplot(y='Year',data=new_df)

# %%
sns.countplot(y='Language of Original Document',data=new_df)

# %%
new_df['Issue'].value_counts()
# Out:
# 1                    34
# 2                    27
# 4                    23
# 3                    15
# 5                     8
# 6                     7
# 3-4                   7
# 2-4                   4
# PART 2                4
# 11                    3
# 1-2                   2
# 8                     2
# 10                    1
# 12                    1
# 2 SPEC.               1
# 26                    1
# sp1                   1
# PART 3                1
# SUPPL. 2              1
# 42                    1
# 7                     1
# 2 Special Issue 6     1
# 9                     1
# Name: Issue, dtype: int64

# %%
sns.countplot(y='Issue',data=new_df)

# %%
new_df['Publisher'].value_counts()
# Out:
# Inderscience Publishers                                                      60
# Institute of Electrical and Electronics Engineers Inc.                        8
# Springer Verlag                                                               8
# IGI Global                                                                    5
# Emerald Group Publishing Ltd.                                                 3
# Friedr. Vieweg und Sohn Verlags GmbH                                          2
# Cambridge University Press                                                    2
# Elsevier Ltd                                                                  2
# SAGE Publications Ltd                                                         2
# CRC Press                                                                     2
# Elsevier Inc.                                                                 2
# Springer New York LLC                                                         2
# ...
